# %% [markdown]
# ## Experiment option
#
# 1. Try different models:
# - LSTM/GRU Networks: The starter code already includes a simple LSTM model. This is a good starting point as temporal dependencies are important.
# - Transformer-based models: Could capture long-range dependencies better than LSTMs.
# - Graph Neural Networks (GNNs): Especially useful if you model the skeleton as a graph structure.
#
# 2. Bio-mechanical Constraints
# - Loss function constraints: Add penalty terms to your loss function that increase when predictions violate biomechanical constraints.
# - Post-processing corrections: Apply corrections to predictions that violate constraints.
# - Constrained outputs: Use activation functions that limit the output range.

# %% [markdown]
# ## Load data

# %%
import glob
import matplotlib.pyplot as plt
import numpy as np

from preprocess import *

# %%
filenames = glob.glob('../data/*.npz')
assert len(filenames) > 0, 'No data files found in ./data/'

filename = filenames[1]
data = np.load(filename)
print('Data containing:')
[print(f'Array {f} of shape {data[f].shape}') for f in data.files];
# Out:
# Data containing:
# Array time of shape (596,)
# Array leftShoulderPosRel of shape (596, 3)
# Array rightShoulderPosRel of shape (596, 3)
# Array leftElbowPosRel of shape (596, 3)
# Array rightElbowPosRel of shape (596, 3)
# Array leftWristPosRel of shape (596, 3)
# Array rightWristPosRel of shape (596, 3)
# Array leftFingerPosRel of shape (596, 3)
# Array rightFingerPosRel of shape (596, 3)
# Array accelerationLeftLoc of shape (596, 3)
# Array accelerationRightLoc of shape (596, 3)
# Array gyroLeftLoc of shape (596, 3)
# Array gyroRightLoc of shape (596, 3)

# %%
dt = np.diff(data['time'])
SAMPLE_RATE = 1.0 / np.mean(dt)
print('Sample rate:', SAMPLE_RATE)
# Out:
# Sample rate: 60.0

# %% [markdown]
# ## Visualize data

# %% [markdown]
# #### Visualize MoCap

# %%
fig, ax = plt.subplots(2, 2, figsize=(16,14))

t = 0 # Select frame to observe
time, torso, left_arm, right_arm = extractMoCap(data)

[ax[i,j].set_xlim(-1,1) for i in range(2) for j in range(2)]
[ax[i,j].set_ylim(-1,1) for i in range(2) for j in range(2)]

ax[0,0].set_title('View from behind')
ax[0,0].set_xlabel('Lateral')
ax[0,0].set_ylabel('Vertical')
t_00, = ax[0,0].plot(torso[t,:,0], torso[t,:,2], '-o', label='Torso')
l_00, = ax[0,0].plot(left_arm[t,:,0], left_arm[t,:,2], '-o', label='Left Arm')
r_00, = ax[0,0].plot(right_arm[t,:,0], right_arm[t,:,2], '-o', label='Right Arm')
ax[0,0].legend(loc='upper left')

ax[0,1].set_title('View from right')
ax[0,1].set_xlabel('Frontal')
ax[0,1].set_ylabel('Vertical')
t_01, = ax[0,1].plot(torso[t,:,1], torso[t,:,2], '-o', label='Torso')
l_01, = ax[0,1].plot(left_arm[t,:,1], left_arm[t,:,2], '-o', label='Left Arm')
r_01, = ax[0,1].plot(right_arm[t,:,1], right_arm[t,:,2], '-o', label='Right Arm')
ax[0,1].legend(loc='upper left')

ax[1,0].set_title('View from top')
ax[1,0].set_xlabel('Lateral')
ax[1,0].set_ylabel('Frontal')
t_10, = ax[1,0].plot(torso[t,:,0], torso[t,:,1], '-o', label='Torso')
l_10, = ax[1,0].plot(left_arm[t,:,0], left_arm[t,:,1], '-o', label='Left Arm')
r_10, = ax[1,0].plot(right_arm[t,:,0], right_arm[t,:,1], '-o', label='Right Arm')
ax[1,0].legend(loc='upper left')

ax[1,1].set_axis_off()

# %% [markdown]
# #### Visualize IMU

# %%
fig, ax = plt.subplots(2, 2, figsize=(16,6), sharex=True, sharey='row')

time, left_acc, right_acc, left_gyro, right_gyro = extractIMU(data)

ax[0,0].set_ylim(-20,20)
ax[1,0].set_ylim(-np.pi,np.pi)

ax[0,0].set_title('Left sensor acceleration')
ax[0,0].set_ylabel('Acceleration (m/s^2)')
ax[0,0].plot(time, left_acc, label=['x', 'y', 'z'])
ax[0,0].legend(loc='upper left')

ax[0,1].set_title('Right sensor acceleration')
ax[0,1].plot(time, right_acc, label=['x', 'y', 'z'])
ax[0,1].legend(loc='upper left')

ax[1,0].set_title('Left sensor gyroscope')
ax[1,0].set_xlabel('Time (s)')
ax[1,0].set_ylabel('Gyroscope (rad/s)')
ax[1,0].plot(time, left_gyro, label=['x', 'y', 'z'])
ax[1,0].legend(loc='upper left')

ax[1,1].set_title('Right sensor gyroscope')
ax[1,1].set_xlabel('Time (s)')
ax[1,1].plot(time, right_gyro, label=['x', 'y', 'z'])
ax[1,1].legend(loc='upper left')

# %%
fig, ax = plt.subplots(2, 2, figsize=(16,6), sharex=True, sharey='row')

left_acc_filt, left_gyro_filt = fuse_and_rotate(left_acc, left_gyro, sample_rate=SAMPLE_RATE)

right_acc_filt, right_gyro_filt = fuse_and_rotate(right_acc, right_gyro, sample_rate=SAMPLE_RATE)

ax[0,0].set_ylim(-20,20)
ax[1,0].set_ylim(-np.pi,np.pi)

ax[0,0].set_title('Left sensor acceleration - filtered')
ax[0,0].set_ylabel('Acceleration (m/s^2)')
ax[0,0].plot(time, left_acc_filt, label=['x', 'y', 'z'])
ax[0,0].legend(loc='upper left')

ax[0,1].set_title('Right sensor acceleration - filtered')
ax[0,1].plot(time, right_acc_filt, label=['x', 'y', 'z'])
ax[0,1].legend(loc='upper left')

ax[1,0].set_title('Left sensor gyroscope - filtered')
ax[1,0].set_xlabel('Time (s)')
ax[1,0].set_ylabel('Gyroscope (rad/s)')
ax[1,0].plot(time, left_gyro_filt, label=['x', 'y', 'z'])
ax[1,0].legend(loc='upper left')

ax[1,1].set_title('Right sensor gyroscope - filtered')
ax[1,1].set_xlabel('Time (s)')
ax[1,1].plot(time, right_gyro_filt, label=['x', 'y', 'z'])
ax[1,1].legend(loc='upper left')

# %% [markdown]
# ### Plot PSD

# %%
from scipy.signal import welch

def plot_imu_psd(raw_imu_signals, sample_rate=60.0, sensor_label='IMU Sensor'):
    """
    Plot Power Spectral Density (PSD) for each axis of IMU signals.

    Args:
        raw_imu_signals: np.ndarray of shape (T, 3), where T is timesteps and 3 axes.
        sample_rate: Sampling frequency in Hz.
        sensor_label: Label for the sensor (e.g., 'Left Accelerometer').
    """
    # Compute PSD using Welch's method
    f, Pxx = welch(raw_imu_signals, fs=sample_rate, axis=0, nperseg=1024)

    # Plot each axis on the same figure
    plt.figure(figsize=(8, 5))
    plt.semilogy(f, Pxx[:, 0], label='Axis X')
    plt.semilogy(f, Pxx[:, 1], label='Axis Y')
    plt.semilogy(f, Pxx[:, 2], label='Axis Z')
    
    plt.title(f'Power Spectral Density - {sensor_label}')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('PSD (V^2/Hz)')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()

plot_imu_psd(left_acc_filt, sample_rate=60.0, sensor_label='Left Accelerometer')
plot_imu_psd(right_acc_filt, sample_rate=60.0, sensor_label='Right Accelerometer')
plot_imu_psd(left_gyro, sample_rate=60.0, sensor_label='Left Gyroscope')
plot_imu_psd(right_gyro, sample_rate=60.0, sensor_label='Right Gyroscope')
# Out:
# /home/patrick-do/Documents/Projects/CS690R_Project/cs690r/venv/lib/python3.12/site-packages/scipy/signal/_spectral_py.py:790: UserWarning: nperseg = 1024 is greater than input length  = 596, using nperseg = 596
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,

# %% [markdown]
# Plot FFT

# %%
# import numpy as np

# def plot_imu_fft(raw_imu_signals, sample_rate=60.0, sensor_label='IMU Sensor'):
#     """
#     Plot FFT magnitude spectrum for each axis of IMU signals.

#     Args:
#         raw_imu_signals: np.ndarray of shape (T, 3), where T is timesteps and 3 axes.
#         sample_rate: Sampling frequency in Hz.
#         sensor_label: Label for the sensor (e.g., 'Left Accelerometer').
#     """
#     T = raw_imu_signals.shape[0]
#     # Compute FFT for each axis
#     freqs = np.fft.rfftfreq(T, d=1.0 / sample_rate)  # frequencies
#     fft_vals = np.fft.rfft(raw_imu_signals, axis=0)   # FFT values

#     axes = ['X', 'Y', 'Z']
#     for i in range(3):
#         magnitude = np.abs(fft_vals[:, i]) / T  # normalize
#         plt.figure(figsize=(8, 4))
#         plt.plot(freqs, magnitude)
#         plt.title(f'FFT Magnitude Spectrum - {sensor_label} Axis {axes[i]}')
#         plt.xlabel('Frequency (Hz)')
#         plt.ylabel('Magnitude')
#         plt.grid(True, linestyle='--', alpha=0.5)
#         plt.tight_layout()
#         plt.show()

# # Example usage with your raw data arrays:
# plot_imu_fft(left_acc_filt,  sample_rate=60.0, sensor_label='Left Accelerometer')
# plot_imu_fft(right_acc_filt, sample_rate=60.0, sensor_label='Right Accelerometer')
# plot_imu_fft(left_gyro, sample_rate=60.0, sensor_label='Left Gyroscope')
# plot_imu_fft(right_gyro, sample_rate=60.0, sensor_label='Right Gyroscope')

# %% [markdown]
# ## Create PyTorch dataset

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

from dataset import *
from losses import *

# %% [markdown]
# #### Get subjects

# %%
subjects = np.unique([f.split('_')[-2] for f in filenames])

print(f'Found subjects: {subjects}')
# Out:
# Found subjects: ['s1' 's10' 's2' 's3' 's4' 's5' 's6' 's7' 's8' 's9']

# %% [markdown]
# #### Split train/test using LOSO

# %%
np.random.seed(42) # For reproducibility
permutation = np.random.permutation(len(subjects))
train_subjects = subjects[permutation[:-1]]
test_subjects = subjects[permutation[-1:]]

print(f'Training on subjects: {train_subjects}')
print(f'Testing on subjects: {test_subjects}')
# Out:
# Training on subjects: ['s8' 's10' 's5' 's1' 's7' 's2' 's9' 's4' 's3']
# Testing on subjects: ['s6']

# %% [markdown]
# #### Instantiate datasets

# %%
# train_dataset = CustomDataset([f for f in filenames if any(s == f.split('_')[-2] for s in train_subjects)])
# test_dataset = CustomDataset([f for f in filenames if any(s == f.split('_')[-2] for s in test_subjects)])

window_size = 60
window_shift = 15
isFilter = False # Preprocessing flag
train_dataset = IMUDataset([f for f in filenames if any(s == f.split('_')[-2] for s in train_subjects)], 
                           filter=isFilter, 
                           window_size=window_size, 
                           window_shift=window_shift)
test_dataset = IMUDataset([f for f in filenames if any(s == f.split('_')[-2] for s in test_subjects)], 
                          filter=isFilter, 
                          window_size=window_size, 
                          window_shift=window_shift)

# %% [markdown]
# #### Collate function to deal with different lengths

# %%
def collate_fn(batch):
    longest_sample = max(batch, key=lambda x: len(x['time']))
    max_len = len(longest_sample['time']) # max_len
    padded_batch = []

    for sample in batch:
        padding_len = max_len - len(sample['time'])
        padded_sample = {}
        padded_sample['mocap'] = torch.cat([sample['mocap'],
                                            sample['mocap'][-1:].repeat(padding_len,1,1)]) # (max_len, 8, 3)
        acc = torch.cat([sample['imu'][:,[0,1]],
                         sample['imu'][-1:,[0,1]].repeat(padding_len,1,1)]) # (max_len, 2, 3)
        gyro = torch.cat([sample['imu'][:,[2,3]],
                          torch.zeros_like(sample['imu'][-1:,[2,3]]).repeat(padding_len,1,1)]) # (max_len, 2, 3)
        padded_sample['imu'] = torch.cat([acc, gyro], dim=1) # (max_len, 4, 3)
        padded_batch.append(padded_sample)

    return {'time': longest_sample['time'],
            'mocap': torch.stack([sample['mocap'] for sample in padded_batch]),
            'imu': torch.stack([sample['imu'] for sample in padded_batch])}

# %% [markdown]
# #### Instantiate dataloaders

# %%
batch_size = 32
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, collate_fn=collate_fn)

# %% [markdown]
# ## Train model

# %% [markdown]
# #### Instantiate model

# %%
from model import *

### MODEL OPTION 1: Baseline LSTM -------------------------------

# model = SimpleNN(input_size=4*3, hidden_size=8*3, num_layers=2) 

### -------------------------------------------------------------


### MODEL OPTION 2: ConvTransformer -----------------------------

# model = ConvTransformer(
#     input_dim=12,
#     transformer_dim=64,
#     window_size=window_size,
#     nhead=8,
#     dim_feedforward=256,
#     transformer_dropout=0.1,
#     transformer_activation="gelu",
#     num_encoder_layers=6,
#     encode_position=True
# )

###---------------------------------------------------------------


### MODEL OPTION 3: Bidirectional LSTM ---------------------------

model = BiLSTM(input_size=12, hidden_size=12, num_layers=2)

###---------------------------------------------------------------

save_path = 'bilstm_noprocess_withcontraints'
os.makedirs(save_path, exist_ok=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# BiLSTM(
#   (lstm): LSTM(12, 12, num_layers=2, batch_first=True, bidirectional=True)
# )

# %% [markdown]
# #### Define criterion

# %%
criterion = nn.MSELoss()

# %% [markdown]
# #### Initialize optimizer

# %%
learning_rate = 1e-4
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Run epochs

# %%
num_epochs = 25

# ⭐ Define loss weights
angle_weight = 0.1
bone_length_weight = 0.2

# Create a dictionary to store metrics
metrics = {
    'train_loss': [],
    'test_loss': [],
    'train_mse': [],
    'test_mse': [],
    'train_angle': [],
    'test_angle': [],
    'train_bone': [],
    'test_bone': []
}

for epoch in range(num_epochs):
    print(f'Running epoch [{epoch+1}/{num_epochs}]')
    
    # Training loop
    model.train()
    epoch_train_loss = 0
    epoch_train_mse = 0
    epoch_train_angle = 0
    epoch_train_bone = 0
    
    for i, batch in enumerate(train_dataloader):
        # Move batch data onto device
        batch = {k: v.to(device, non_blocking=True) for k, v in batch.items()}
        
        # Forward pass
        outputs = model(batch['imu'])
        outputs_reshaped = outputs.view(*batch['mocap'].shape)
        
        # Calculate different loss components
        mse_loss = F.mse_loss(outputs_reshaped, batch['mocap'])
        angle_loss = angle_constraint_loss(outputs_reshaped, alpha=angle_weight)
        bone_loss = bone_length_consistency_loss(outputs_reshaped, alpha=bone_length_weight)
        
        # ⭐ Combine losses
        # total_loss = mse_loss + angle_loss + bone_loss
        total_loss = mse_loss
        
        # Backward and optimize
        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()
        
        # Accumulate losses
        epoch_train_loss += total_loss.item()
        epoch_train_mse += mse_loss.item()
        epoch_train_angle += angle_loss.item()
        epoch_train_bone += bone_loss.item()
        
        if (i+1) % 200 == 0:
            print(f'Train Step [{i+1}/{len(train_dataloader)}], Total Loss: {total_loss.item():.4f}, '
                  f'MSE: {mse_loss.item():.4f}, Angle: {angle_loss.item():.4f}, Bone: {bone_loss.item():.4f}')
    
    # Average losses for the epoch
    epoch_train_loss /= len(train_dataloader)
    epoch_train_mse /= len(train_dataloader)
    epoch_train_angle /= len(train_dataloader)
    epoch_train_bone /= len(train_dataloader)
    
    # Store metrics
    metrics['train_loss'].append(epoch_train_loss)
    metrics['train_mse'].append(epoch_train_mse)
    metrics['train_angle'].append(epoch_train_angle)
    metrics['train_bone'].append(epoch_train_bone)
    
    # Evaluation loop
    model.eval()
    epoch_test_loss = 0
    epoch_test_mse = 0
    epoch_test_angle = 0
    epoch_test_bone = 0
    
    with torch.no_grad():
        for i, batch in enumerate(test_dataloader):
            #Move batch data onto device
            batch = {k: v.to(device, non_blocking=True) for k, v in batch.items()}

            outputs = model(batch['imu'])
            outputs_reshaped = outputs.view(*batch['mocap'].shape)
            
            # Calculate different loss components
            mse_loss = F.mse_loss(outputs_reshaped, batch['mocap'])
            angle_loss = angle_constraint_loss(outputs_reshaped, alpha=angle_weight)
            bone_loss = bone_length_consistency_loss(outputs_reshaped, alpha=bone_length_weight)
            
            # Combine losses
            # total_loss = mse_loss + angle_loss + bone_loss
            total_loss = mse_loss
            
            # Accumulate losses
            epoch_test_loss += total_loss.item()
            epoch_test_mse += mse_loss.item()
            epoch_test_angle += angle_loss.item()
            epoch_test_bone += bone_loss.item()
            
            if (i+1) % 200 == 0:
                print(f'Test Step [{i+1}/{len(test_dataloader)}], Total Loss: {total_loss.item():.4f}, '
                      f'MSE: {mse_loss.item():.4f}, Angle: {angle_loss.item():.4f}, Bone: {bone_loss.item():.4f}')
    
    # Average losses for the epoch
    epoch_test_loss /= len(test_dataloader)
    epoch_test_mse /= len(test_dataloader)
    epoch_test_angle /= len(test_dataloader)
    epoch_test_bone /= len(test_dataloader)
    
    # Store metrics
    metrics['test_loss'].append(epoch_test_loss)
    metrics['test_mse'].append(epoch_test_mse)
    metrics['test_angle'].append(epoch_test_angle)
    metrics['test_bone'].append(epoch_test_bone)
    
    print(f'Epoch [{epoch+1}/{num_epochs}], '
          f'Train Loss: {epoch_train_loss:.4f}, Test Loss: {epoch_test_loss:.4f}')
    
    # Save model checkpoint if desired
    if epoch % 5 == 4:
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': epoch_test_loss,
            'metrics': metrics
        }, f'{save_path}/checkpoint_epoch_{epoch}.pth')
# Out:
# Running epoch [1/25]
# Train Step [200/2874], Total Loss: 0.0543, MSE: 0.0543, Angle: 0.0023, Bone: 0.0060
# Train Step [400/2874], Total Loss: 0.0513, MSE: 0.0513, Angle: 0.0000, Bone: 0.0030
# Train Step [600/2874], Total Loss: 0.0320, MSE: 0.0320, Angle: 0.0027, Bone: 0.0044
# Train Step [800/2874], Total Loss: 0.0376, MSE: 0.0376, Angle: 0.0278, Bone: 0.0022
# Train Step [1000/2874], Total Loss: 0.0369, MSE: 0.0369, Angle: 0.3928, Bone: 0.0028
# Train Step [1200/2874], Total Loss: 0.0108, MSE: 0.0108, Angle: 0.3335, Bone: 0.0008
# Train Step [1400/2874], Total Loss: 0.0176, MSE: 0.0176, Angle: 0.0320, Bone: 0.0013
# Train Step [1600/2874], Total Loss: 0.0061, MSE: 0.0061, Angle: 0.0294, Bone: 0.0007
# Train Step [1800/2874], Total Loss: 0.0261, MSE: 0.0261, Angle: 0.0013, Bone: 0.0010
# Train Step [2000/2874], Total Loss: 0.0189, MSE: 0.0189, Angle: 0.0012, Bone: 0.0009
# Train Step [2200/2874], Total Loss: 0.0251, MSE: 0.0251, Angle: 0.0630, Bone: 0.0015
# Train Step [2400/2874], Total Loss: 0.0193, MSE: 0.0193, Angle: 0.0760, Bone: 0.0016
# Train Step [2600/2874], Total Loss: 0.0196, MSE: 0.0196, Angle: 0.1289, Bone: 0.0006
# Train Step [2800/2874], Total Loss: 0.0048, MSE: 0.0048, Angle: 0.0106, Bone: 0.0003
# Test Step [200/381], Total Loss: 0.0173, MSE: 0.0173, Angle: 0.1638, Bone: 0.0011
# Epoch [1/25], Train Loss: 0.0296, Test Loss: 0.0156
# Running epoch [2/25]
# Train Step [200/2874], Total Loss: 0.0108, MSE: 0.0108, Angle: 0.0833, Bone: 0.0014
# Train Step [400/2874], Total Loss: 0.0217, MSE: 0.0217, Angle: 0.0589, Bone: 0.0011
# Train Step [600/2874], Total Loss: 0.0109, MSE: 0.0109, Angle: 0.0110, Bone: 0.0013
# Train Step [800/2874], Total Loss: 0.0171, MSE: 0.0171, Angle: 0.0177, Bone: 0.0008
# Train Step [1000/2874], Total Loss: 0.0153, MSE: 0.0153, Angle: 0.2491, Bone: 0.0010
# Train Step [1200/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0003
# Train Step [1400/2874], Total Loss: 0.0131, MSE: 0.0131, Angle: 0.1236, Bone: 0.0004
# Train Step [1600/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.3190, Bone: 0.0003
# Train Step [1800/2874], Total Loss: 0.0185, MSE: 0.0185, Angle: 0.0007, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0119, MSE: 0.0119, Angle: 0.0538, Bone: 0.0004
# Train Step [2200/2874], Total Loss: 0.0212, MSE: 0.0212, Angle: 0.1185, Bone: 0.0008
# Train Step [2400/2874], Total Loss: 0.0162, MSE: 0.0162, Angle: 0.0663, Bone: 0.0009
# Train Step [2600/2874], Total Loss: 0.0159, MSE: 0.0159, Angle: 0.1109, Bone: 0.0004
# Train Step [2800/2874], Total Loss: 0.0031, MSE: 0.0031, Angle: 0.0131, Bone: 0.0002
# Test Step [200/381], Total Loss: 0.0115, MSE: 0.0115, Angle: 0.3837, Bone: 0.0006
# Epoch [2/25], Train Loss: 0.0145, Test Loss: 0.0115
# Running epoch [3/25]
# Train Step [200/2874], Total Loss: 0.0098, MSE: 0.0098, Angle: 0.0356, Bone: 0.0009
# Train Step [400/2874], Total Loss: 0.0233, MSE: 0.0233, Angle: 0.2106, Bone: 0.0008
# Train Step [600/2874], Total Loss: 0.0073, MSE: 0.0073, Angle: 0.0079, Bone: 0.0006
# Train Step [800/2874], Total Loss: 0.0105, MSE: 0.0105, Angle: 0.0124, Bone: 0.0006
# Train Step [1000/2874], Total Loss: 0.0076, MSE: 0.0076, Angle: 0.5942, Bone: 0.0009
# Train Step [1200/2874], Total Loss: 0.0036, MSE: 0.0036, Angle: 0.0000, Bone: 0.0002
# Train Step [1400/2874], Total Loss: 0.0111, MSE: 0.0111, Angle: 0.1794, Bone: 0.0003
# Train Step [1600/2874], Total Loss: 0.0031, MSE: 0.0031, Angle: 0.1549, Bone: 0.0003
# Train Step [1800/2874], Total Loss: 0.0140, MSE: 0.0140, Angle: 0.0030, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0104, MSE: 0.0104, Angle: 0.0880, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0184, MSE: 0.0184, Angle: 0.0645, Bone: 0.0006
# Train Step [2400/2874], Total Loss: 0.0154, MSE: 0.0154, Angle: 0.0699, Bone: 0.0005
# Train Step [2600/2874], Total Loss: 0.0149, MSE: 0.0149, Angle: 0.0902, Bone: 0.0003
# Train Step [2800/2874], Total Loss: 0.0026, MSE: 0.0026, Angle: 0.0290, Bone: 0.0002
# Test Step [200/381], Total Loss: 0.0091, MSE: 0.0091, Angle: 0.6013, Bone: 0.0004
# Epoch [3/25], Train Loss: 0.0123, Test Loss: 0.0101
# Running epoch [4/25]
# Train Step [200/2874], Total Loss: 0.0091, MSE: 0.0091, Angle: 0.0029, Bone: 0.0007
# Train Step [400/2874], Total Loss: 0.0196, MSE: 0.0196, Angle: 0.0018, Bone: 0.0006
# Train Step [600/2874], Total Loss: 0.0051, MSE: 0.0051, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0084, MSE: 0.0084, Angle: 0.0470, Bone: 0.0005
# Train Step [1000/2874], Total Loss: 0.0063, MSE: 0.0063, Angle: 0.7362, Bone: 0.0010
# Train Step [1200/2874], Total Loss: 0.0038, MSE: 0.0038, Angle: 0.0021, Bone: 0.0002
# Train Step [1400/2874], Total Loss: 0.0104, MSE: 0.0104, Angle: 0.1635, Bone: 0.0003
# Train Step [1600/2874], Total Loss: 0.0027, MSE: 0.0027, Angle: 0.0872, Bone: 0.0003
# Train Step [1800/2874], Total Loss: 0.0106, MSE: 0.0106, Angle: 0.0058, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0095, MSE: 0.0095, Angle: 0.1867, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0170, MSE: 0.0170, Angle: 0.0502, Bone: 0.0005
# Train Step [2400/2874], Total Loss: 0.0145, MSE: 0.0145, Angle: 0.1160, Bone: 0.0004
# Train Step [2600/2874], Total Loss: 0.0146, MSE: 0.0146, Angle: 0.0748, Bone: 0.0003
# Train Step [2800/2874], Total Loss: 0.0024, MSE: 0.0024, Angle: 0.0389, Bone: 0.0002
# Test Step [200/381], Total Loss: 0.0082, MSE: 0.0082, Angle: 0.6443, Bone: 0.0003
# Epoch [4/25], Train Loss: 0.0113, Test Loss: 0.0095
# Running epoch [5/25]
# Train Step [200/2874], Total Loss: 0.0089, MSE: 0.0089, Angle: 0.0000, Bone: 0.0006
# Train Step [400/2874], Total Loss: 0.0171, MSE: 0.0171, Angle: 0.0007, Bone: 0.0006
# Train Step [600/2874], Total Loss: 0.0044, MSE: 0.0044, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.0272, Bone: 0.0005
# Train Step [1000/2874], Total Loss: 0.0061, MSE: 0.0061, Angle: 0.8514, Bone: 0.0010
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0039, Bone: 0.0002
# Train Step [1400/2874], Total Loss: 0.0101, MSE: 0.0101, Angle: 0.1594, Bone: 0.0003
# Train Step [1600/2874], Total Loss: 0.0027, MSE: 0.0027, Angle: 0.0918, Bone: 0.0003
# Train Step [1800/2874], Total Loss: 0.0082, MSE: 0.0082, Angle: 0.0202, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0085, MSE: 0.0085, Angle: 0.2651, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0157, MSE: 0.0157, Angle: 0.0909, Bone: 0.0005
# Train Step [2400/2874], Total Loss: 0.0133, MSE: 0.0133, Angle: 0.2111, Bone: 0.0004
# Train Step [2600/2874], Total Loss: 0.0143, MSE: 0.0143, Angle: 0.0741, Bone: 0.0003
# Train Step [2800/2874], Total Loss: 0.0022, MSE: 0.0022, Angle: 0.0397, Bone: 0.0002
# Test Step [200/381], Total Loss: 0.0079, MSE: 0.0079, Angle: 0.5603, Bone: 0.0003
# Epoch [5/25], Train Loss: 0.0107, Test Loss: 0.0091
# Running epoch [6/25]
# Train Step [200/2874], Total Loss: 0.0090, MSE: 0.0090, Angle: 0.0000, Bone: 0.0006
# Train Step [400/2874], Total Loss: 0.0156, MSE: 0.0156, Angle: 0.0034, Bone: 0.0005
# Train Step [600/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0076, MSE: 0.0076, Angle: 0.0390, Bone: 0.0005
# Train Step [1000/2874], Total Loss: 0.0061, MSE: 0.0061, Angle: 0.9310, Bone: 0.0009
# Train Step [1200/2874], Total Loss: 0.0042, MSE: 0.0042, Angle: 0.0045, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0098, MSE: 0.0098, Angle: 0.1534, Bone: 0.0003
# Train Step [1600/2874], Total Loss: 0.0027, MSE: 0.0027, Angle: 0.0952, Bone: 0.0002
# Train Step [1800/2874], Total Loss: 0.0066, MSE: 0.0066, Angle: 0.0546, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.4435, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0145, MSE: 0.0145, Angle: 0.1630, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0123, MSE: 0.0123, Angle: 0.2454, Bone: 0.0004
# Train Step [2600/2874], Total Loss: 0.0139, MSE: 0.0139, Angle: 0.0756, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0020, MSE: 0.0020, Angle: 0.0398, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.4897, Bone: 0.0003
# Epoch [6/25], Train Loss: 0.0102, Test Loss: 0.0087
# Running epoch [7/25]
# Train Step [200/2874], Total Loss: 0.0092, MSE: 0.0092, Angle: 0.0000, Bone: 0.0006
# Train Step [400/2874], Total Loss: 0.0146, MSE: 0.0146, Angle: 0.0197, Bone: 0.0005
# Train Step [600/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.0767, Bone: 0.0005
# Train Step [1000/2874], Total Loss: 0.0061, MSE: 0.0061, Angle: 0.9852, Bone: 0.0008
# Train Step [1200/2874], Total Loss: 0.0042, MSE: 0.0042, Angle: 0.0040, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0096, MSE: 0.0096, Angle: 0.1458, Bone: 0.0002
# Train Step [1600/2874], Total Loss: 0.0027, MSE: 0.0027, Angle: 0.0901, Bone: 0.0002
# Train Step [1800/2874], Total Loss: 0.0057, MSE: 0.0057, Angle: 0.1141, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0072, MSE: 0.0072, Angle: 0.5699, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0134, MSE: 0.0134, Angle: 0.2502, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0116, MSE: 0.0116, Angle: 0.2322, Bone: 0.0004
# Train Step [2600/2874], Total Loss: 0.0137, MSE: 0.0137, Angle: 0.0840, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0019, MSE: 0.0019, Angle: 0.0407, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0074, MSE: 0.0074, Angle: 0.4558, Bone: 0.0003
# Epoch [7/25], Train Loss: 0.0099, Test Loss: 0.0085
# Running epoch [8/25]
# Train Step [200/2874], Total Loss: 0.0094, MSE: 0.0094, Angle: 0.0000, Bone: 0.0005
# Train Step [400/2874], Total Loss: 0.0139, MSE: 0.0139, Angle: 0.0444, Bone: 0.0005
# Train Step [600/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.1167, Bone: 0.0005
# Train Step [1000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0318, Bone: 0.0008
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0029, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0093, MSE: 0.0093, Angle: 0.1386, Bone: 0.0002
# Train Step [1600/2874], Total Loss: 0.0027, MSE: 0.0027, Angle: 0.0823, Bone: 0.0002
# Train Step [1800/2874], Total Loss: 0.0051, MSE: 0.0051, Angle: 0.2209, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0068, MSE: 0.0068, Angle: 0.6811, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0125, MSE: 0.0125, Angle: 0.3454, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0110, MSE: 0.0110, Angle: 0.1919, Bone: 0.0004
# Train Step [2600/2874], Total Loss: 0.0136, MSE: 0.0136, Angle: 0.0982, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0019, MSE: 0.0019, Angle: 0.0407, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0071, MSE: 0.0071, Angle: 0.4465, Bone: 0.0003
# Epoch [8/25], Train Loss: 0.0096, Test Loss: 0.0083
# Running epoch [9/25]
# Train Step [200/2874], Total Loss: 0.0094, MSE: 0.0094, Angle: 0.0000, Bone: 0.0005
# Train Step [400/2874], Total Loss: 0.0134, MSE: 0.0134, Angle: 0.0678, Bone: 0.0005
# Train Step [600/2874], Total Loss: 0.0039, MSE: 0.0039, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.1388, Bone: 0.0005
# Train Step [1000/2874], Total Loss: 0.0058, MSE: 0.0058, Angle: 1.0507, Bone: 0.0007
# Train Step [1200/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0017, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0091, MSE: 0.0091, Angle: 0.1362, Bone: 0.0002
# Train Step [1600/2874], Total Loss: 0.0027, MSE: 0.0027, Angle: 0.0752, Bone: 0.0002
# Train Step [1800/2874], Total Loss: 0.0047, MSE: 0.0047, Angle: 0.3503, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0065, MSE: 0.0065, Angle: 0.7795, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0118, MSE: 0.0118, Angle: 0.4145, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0105, MSE: 0.0105, Angle: 0.1481, Bone: 0.0004
# Train Step [2600/2874], Total Loss: 0.0137, MSE: 0.0137, Angle: 0.1067, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0018, MSE: 0.0018, Angle: 0.0410, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0068, MSE: 0.0068, Angle: 0.4493, Bone: 0.0003
# Epoch [9/25], Train Loss: 0.0094, Test Loss: 0.0082
# Running epoch [10/25]
# Train Step [200/2874], Total Loss: 0.0092, MSE: 0.0092, Angle: 0.0000, Bone: 0.0005
# Train Step [400/2874], Total Loss: 0.0130, MSE: 0.0130, Angle: 0.0860, Bone: 0.0004
# Train Step [600/2874], Total Loss: 0.0037, MSE: 0.0037, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.1434, Bone: 0.0004
# Train Step [1000/2874], Total Loss: 0.0057, MSE: 0.0057, Angle: 1.0762, Bone: 0.0007
# Train Step [1200/2874], Total Loss: 0.0039, MSE: 0.0039, Angle: 0.0008, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0089, MSE: 0.0089, Angle: 0.1356, Bone: 0.0002
# Train Step [1600/2874], Total Loss: 0.0026, MSE: 0.0026, Angle: 0.0700, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0045, MSE: 0.0045, Angle: 0.4449, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0064, MSE: 0.0064, Angle: 0.8470, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0112, MSE: 0.0112, Angle: 0.4590, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0102, MSE: 0.0102, Angle: 0.1124, Bone: 0.0004
# Train Step [2600/2874], Total Loss: 0.0137, MSE: 0.0137, Angle: 0.1094, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0018, MSE: 0.0018, Angle: 0.0417, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0065, MSE: 0.0065, Angle: 0.4664, Bone: 0.0003
# Epoch [10/25], Train Loss: 0.0092, Test Loss: 0.0080
# Running epoch [11/25]
# Train Step [200/2874], Total Loss: 0.0089, MSE: 0.0089, Angle: 0.0000, Bone: 0.0004
# Train Step [400/2874], Total Loss: 0.0127, MSE: 0.0127, Angle: 0.0981, Bone: 0.0004
# Train Step [600/2874], Total Loss: 0.0036, MSE: 0.0036, Angle: 0.0000, Bone: 0.0005
# Train Step [800/2874], Total Loss: 0.0076, MSE: 0.0076, Angle: 0.1494, Bone: 0.0004
# Train Step [1000/2874], Total Loss: 0.0056, MSE: 0.0056, Angle: 1.0991, Bone: 0.0006
# Train Step [1200/2874], Total Loss: 0.0039, MSE: 0.0039, Angle: 0.0002, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0088, MSE: 0.0088, Angle: 0.1355, Bone: 0.0002
# Train Step [1600/2874], Total Loss: 0.0026, MSE: 0.0026, Angle: 0.0667, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0043, MSE: 0.0043, Angle: 0.5221, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0062, MSE: 0.0062, Angle: 0.8848, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0108, MSE: 0.0108, Angle: 0.4965, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0100, MSE: 0.0100, Angle: 0.0893, Bone: 0.0003
# Train Step [2600/2874], Total Loss: 0.0138, MSE: 0.0138, Angle: 0.1106, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0018, MSE: 0.0018, Angle: 0.0424, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0063, MSE: 0.0063, Angle: 0.4866, Bone: 0.0003
# Epoch [11/25], Train Loss: 0.0091, Test Loss: 0.0079
# Running epoch [12/25]
# Train Step [200/2874], Total Loss: 0.0086, MSE: 0.0086, Angle: 0.0000, Bone: 0.0004
# Train Step [400/2874], Total Loss: 0.0123, MSE: 0.0123, Angle: 0.1062, Bone: 0.0004
# Train Step [600/2874], Total Loss: 0.0035, MSE: 0.0035, Angle: 0.0000, Bone: 0.0004
# Train Step [800/2874], Total Loss: 0.0076, MSE: 0.0076, Angle: 0.1630, Bone: 0.0004
# Train Step [1000/2874], Total Loss: 0.0055, MSE: 0.0055, Angle: 1.1186, Bone: 0.0006
# Train Step [1200/2874], Total Loss: 0.0039, MSE: 0.0039, Angle: 0.0000, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0086, MSE: 0.0086, Angle: 0.1381, Bone: 0.0002
# Train Step [1600/2874], Total Loss: 0.0026, MSE: 0.0026, Angle: 0.0645, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0042, MSE: 0.0042, Angle: 0.5845, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0062, MSE: 0.0062, Angle: 0.9019, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0105, MSE: 0.0105, Angle: 0.5315, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0098, MSE: 0.0098, Angle: 0.0800, Bone: 0.0003
# Train Step [2600/2874], Total Loss: 0.0139, MSE: 0.0139, Angle: 0.1116, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0018, MSE: 0.0018, Angle: 0.0433, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.4940, Bone: 0.0003
# Epoch [12/25], Train Loss: 0.0090, Test Loss: 0.0078
# Running epoch [13/25]
# Train Step [200/2874], Total Loss: 0.0082, MSE: 0.0082, Angle: 0.0000, Bone: 0.0004
# Train Step [400/2874], Total Loss: 0.0119, MSE: 0.0119, Angle: 0.1108, Bone: 0.0004
# Train Step [600/2874], Total Loss: 0.0034, MSE: 0.0034, Angle: 0.0000, Bone: 0.0004
# Train Step [800/2874], Total Loss: 0.0075, MSE: 0.0075, Angle: 0.1829, Bone: 0.0004
# Train Step [1000/2874], Total Loss: 0.0054, MSE: 0.0054, Angle: 1.1361, Bone: 0.0006
# Train Step [1200/2874], Total Loss: 0.0039, MSE: 0.0039, Angle: 0.0000, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0084, MSE: 0.0084, Angle: 0.1403, Bone: 0.0002
# Train Step [1600/2874], Total Loss: 0.0025, MSE: 0.0025, Angle: 0.0630, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.6394, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0061, MSE: 0.0061, Angle: 0.9078, Bone: 0.0003
# Train Step [2200/2874], Total Loss: 0.0103, MSE: 0.0103, Angle: 0.5647, Bone: 0.0004
# Train Step [2400/2874], Total Loss: 0.0097, MSE: 0.0097, Angle: 0.0773, Bone: 0.0003
# Train Step [2600/2874], Total Loss: 0.0140, MSE: 0.0140, Angle: 0.1128, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0018, MSE: 0.0018, Angle: 0.0442, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0058, MSE: 0.0058, Angle: 0.4827, Bone: 0.0003
# Epoch [13/25], Train Loss: 0.0089, Test Loss: 0.0077
# Running epoch [14/25]
# Train Step [200/2874], Total Loss: 0.0079, MSE: 0.0079, Angle: 0.0000, Bone: 0.0004
# Train Step [400/2874], Total Loss: 0.0116, MSE: 0.0116, Angle: 0.1133, Bone: 0.0004
# Train Step [600/2874], Total Loss: 0.0033, MSE: 0.0033, Angle: 0.0000, Bone: 0.0004
# Train Step [800/2874], Total Loss: 0.0074, MSE: 0.0074, Angle: 0.2066, Bone: 0.0004
# Train Step [1000/2874], Total Loss: 0.0054, MSE: 0.0054, Angle: 1.1568, Bone: 0.0006
# Train Step [1200/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0082, MSE: 0.0082, Angle: 0.1435, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0025, MSE: 0.0025, Angle: 0.0619, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.6912, Bone: 0.0004
# Train Step [2000/2874], Total Loss: 0.0061, MSE: 0.0061, Angle: 0.9132, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0102, MSE: 0.0102, Angle: 0.5979, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0096, MSE: 0.0096, Angle: 0.0758, Bone: 0.0003
# Train Step [2600/2874], Total Loss: 0.0140, MSE: 0.0140, Angle: 0.1157, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0449, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0057, MSE: 0.0057, Angle: 0.4558, Bone: 0.0003
# Epoch [14/25], Train Loss: 0.0088, Test Loss: 0.0077
# Running epoch [15/25]
# Train Step [200/2874], Total Loss: 0.0076, MSE: 0.0076, Angle: 0.0000, Bone: 0.0003
# Train Step [400/2874], Total Loss: 0.0113, MSE: 0.0113, Angle: 0.1145, Bone: 0.0004
# Train Step [600/2874], Total Loss: 0.0032, MSE: 0.0032, Angle: 0.0000, Bone: 0.0004
# Train Step [800/2874], Total Loss: 0.0074, MSE: 0.0074, Angle: 0.2325, Bone: 0.0004
# Train Step [1000/2874], Total Loss: 0.0053, MSE: 0.0053, Angle: 1.1767, Bone: 0.0006
# Train Step [1200/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0081, MSE: 0.0081, Angle: 0.1474, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0025, MSE: 0.0025, Angle: 0.0609, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.7396, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.9295, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0101, MSE: 0.0101, Angle: 0.6312, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0095, MSE: 0.0095, Angle: 0.0744, Bone: 0.0003
# Train Step [2600/2874], Total Loss: 0.0140, MSE: 0.0140, Angle: 0.1197, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0457, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0055, MSE: 0.0055, Angle: 0.4195, Bone: 0.0003
# Epoch [15/25], Train Loss: 0.0087, Test Loss: 0.0076
# Running epoch [16/25]
# Train Step [200/2874], Total Loss: 0.0073, MSE: 0.0073, Angle: 0.0000, Bone: 0.0003
# Train Step [400/2874], Total Loss: 0.0110, MSE: 0.0110, Angle: 0.1152, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0031, MSE: 0.0031, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0073, MSE: 0.0073, Angle: 0.2584, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0052, MSE: 0.0052, Angle: 1.1951, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0080, MSE: 0.0080, Angle: 0.1506, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0025, MSE: 0.0025, Angle: 0.0605, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0039, MSE: 0.0039, Angle: 0.7841, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.9611, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0100, MSE: 0.0100, Angle: 0.6632, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0094, MSE: 0.0094, Angle: 0.0715, Bone: 0.0003
# Train Step [2600/2874], Total Loss: 0.0140, MSE: 0.0140, Angle: 0.1245, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0461, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0054, MSE: 0.0054, Angle: 0.3831, Bone: 0.0003
# Epoch [16/25], Train Loss: 0.0086, Test Loss: 0.0075
# Running epoch [17/25]
# Train Step [200/2874], Total Loss: 0.0071, MSE: 0.0071, Angle: 0.0000, Bone: 0.0003
# Train Step [400/2874], Total Loss: 0.0108, MSE: 0.0108, Angle: 0.1157, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0031, MSE: 0.0031, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0072, MSE: 0.0072, Angle: 0.2833, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0052, MSE: 0.0052, Angle: 1.2127, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0001
# Train Step [1400/2874], Total Loss: 0.0079, MSE: 0.0079, Angle: 0.1565, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0024, MSE: 0.0024, Angle: 0.0598, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0038, MSE: 0.0038, Angle: 0.8302, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.9849, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0099, MSE: 0.0099, Angle: 0.6933, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0093, MSE: 0.0093, Angle: 0.0679, Bone: 0.0003
# Train Step [2600/2874], Total Loss: 0.0140, MSE: 0.0140, Angle: 0.1290, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0467, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0053, MSE: 0.0053, Angle: 0.3514, Bone: 0.0003
# Epoch [17/25], Train Loss: 0.0086, Test Loss: 0.0075
# Running epoch [18/25]
# Train Step [200/2874], Total Loss: 0.0069, MSE: 0.0069, Angle: 0.0000, Bone: 0.0003
# Train Step [400/2874], Total Loss: 0.0107, MSE: 0.0107, Angle: 0.1159, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0030, MSE: 0.0030, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0071, MSE: 0.0071, Angle: 0.3058, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0051, MSE: 0.0051, Angle: 1.2298, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0040, MSE: 0.0040, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0078, MSE: 0.0078, Angle: 0.1618, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0024, MSE: 0.0024, Angle: 0.0591, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0038, MSE: 0.0038, Angle: 0.8745, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0065, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0098, MSE: 0.0098, Angle: 0.7184, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0092, MSE: 0.0092, Angle: 0.0646, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0139, MSE: 0.0139, Angle: 0.1339, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0471, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0052, MSE: 0.0052, Angle: 0.3269, Bone: 0.0003
# Epoch [18/25], Train Loss: 0.0085, Test Loss: 0.0074
# Running epoch [19/25]
# Train Step [200/2874], Total Loss: 0.0067, MSE: 0.0067, Angle: 0.0000, Bone: 0.0003
# Train Step [400/2874], Total Loss: 0.0105, MSE: 0.0105, Angle: 0.1161, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0030, MSE: 0.0030, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0070, MSE: 0.0070, Angle: 0.3262, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0051, MSE: 0.0051, Angle: 1.2452, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.1663, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0024, MSE: 0.0024, Angle: 0.0585, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0037, MSE: 0.0037, Angle: 0.9139, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0256, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0098, MSE: 0.0098, Angle: 0.7367, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0091, MSE: 0.0091, Angle: 0.0596, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0139, MSE: 0.0139, Angle: 0.1386, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0474, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0052, MSE: 0.0052, Angle: 0.3174, Bone: 0.0003
# Epoch [19/25], Train Loss: 0.0085, Test Loss: 0.0074
# Running epoch [20/25]
# Train Step [200/2874], Total Loss: 0.0066, MSE: 0.0066, Angle: 0.0000, Bone: 0.0003
# Train Step [400/2874], Total Loss: 0.0103, MSE: 0.0103, Angle: 0.1163, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0029, MSE: 0.0029, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0069, MSE: 0.0069, Angle: 0.3451, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0051, MSE: 0.0051, Angle: 1.2608, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0077, MSE: 0.0077, Angle: 0.1704, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0024, MSE: 0.0024, Angle: 0.0579, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0037, MSE: 0.0037, Angle: 0.9494, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0413, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0097, MSE: 0.0097, Angle: 0.7481, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0091, MSE: 0.0091, Angle: 0.0546, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0138, MSE: 0.0138, Angle: 0.1435, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0474, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0051, MSE: 0.0051, Angle: 0.3211, Bone: 0.0003
# Epoch [20/25], Train Loss: 0.0084, Test Loss: 0.0073
# Running epoch [21/25]
# Train Step [200/2874], Total Loss: 0.0064, MSE: 0.0064, Angle: 0.0000, Bone: 0.0002
# Train Step [400/2874], Total Loss: 0.0102, MSE: 0.0102, Angle: 0.1165, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0029, MSE: 0.0029, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0068, MSE: 0.0068, Angle: 0.3630, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0050, MSE: 0.0050, Angle: 1.2777, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0076, MSE: 0.0076, Angle: 0.1742, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0024, MSE: 0.0024, Angle: 0.0572, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0037, MSE: 0.0037, Angle: 0.9841, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0527, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0097, MSE: 0.0097, Angle: 0.7565, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0090, MSE: 0.0090, Angle: 0.0488, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0137, MSE: 0.0137, Angle: 0.1475, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0473, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0051, MSE: 0.0051, Angle: 0.3281, Bone: 0.0002
# Epoch [21/25], Train Loss: 0.0084, Test Loss: 0.0073
# Running epoch [22/25]
# Train Step [200/2874], Total Loss: 0.0063, MSE: 0.0063, Angle: 0.0000, Bone: 0.0002
# Train Step [400/2874], Total Loss: 0.0101, MSE: 0.0101, Angle: 0.1169, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0029, MSE: 0.0029, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0067, MSE: 0.0067, Angle: 0.3795, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0050, MSE: 0.0050, Angle: 1.2939, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0076, MSE: 0.0076, Angle: 0.1778, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0023, MSE: 0.0023, Angle: 0.0567, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0036, MSE: 0.0036, Angle: 1.0150, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0620, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0096, MSE: 0.0096, Angle: 0.7631, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0089, MSE: 0.0089, Angle: 0.0426, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0136, MSE: 0.0136, Angle: 0.1511, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0471, Bone: 0.0001
# Test Step [200/381], Total Loss: 0.0051, MSE: 0.0051, Angle: 0.3348, Bone: 0.0002
# Epoch [22/25], Train Loss: 0.0083, Test Loss: 0.0073
# Running epoch [23/25]
# Train Step [200/2874], Total Loss: 0.0062, MSE: 0.0062, Angle: 0.0000, Bone: 0.0002
# Train Step [400/2874], Total Loss: 0.0100, MSE: 0.0100, Angle: 0.1173, Bone: 0.0003
# Train Step [600/2874], Total Loss: 0.0028, MSE: 0.0028, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0065, MSE: 0.0065, Angle: 0.3963, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0050, MSE: 0.0050, Angle: 1.3093, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0075, MSE: 0.0075, Angle: 0.1812, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0023, MSE: 0.0023, Angle: 0.0560, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0036, MSE: 0.0036, Angle: 1.0434, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0679, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0095, MSE: 0.0095, Angle: 0.7708, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0088, MSE: 0.0088, Angle: 0.0351, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0136, MSE: 0.0136, Angle: 0.1542, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0017, MSE: 0.0017, Angle: 0.0467, Bone: 0.0000
# Test Step [200/381], Total Loss: 0.0050, MSE: 0.0050, Angle: 0.3419, Bone: 0.0002
# Epoch [23/25], Train Loss: 0.0083, Test Loss: 0.0072
# Running epoch [24/25]
# Train Step [200/2874], Total Loss: 0.0061, MSE: 0.0061, Angle: 0.0000, Bone: 0.0002
# Train Step [400/2874], Total Loss: 0.0099, MSE: 0.0099, Angle: 0.1182, Bone: 0.0002
# Train Step [600/2874], Total Loss: 0.0028, MSE: 0.0028, Angle: 0.0000, Bone: 0.0003
# Train Step [800/2874], Total Loss: 0.0064, MSE: 0.0064, Angle: 0.4127, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0049, MSE: 0.0049, Angle: 1.3253, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0075, MSE: 0.0075, Angle: 0.1848, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0023, MSE: 0.0023, Angle: 0.0556, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0036, MSE: 0.0036, Angle: 1.0713, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0725, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0094, MSE: 0.0094, Angle: 0.7795, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0087, MSE: 0.0087, Angle: 0.0280, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0135, MSE: 0.0135, Angle: 0.1571, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0016, MSE: 0.0016, Angle: 0.0465, Bone: 0.0000
# Test Step [200/381], Total Loss: 0.0050, MSE: 0.0050, Angle: 0.3498, Bone: 0.0002
# Epoch [24/25], Train Loss: 0.0082, Test Loss: 0.0072
# Running epoch [25/25]
# Train Step [200/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.0000, Bone: 0.0002
# Train Step [400/2874], Total Loss: 0.0099, MSE: 0.0099, Angle: 0.1193, Bone: 0.0002
# Train Step [600/2874], Total Loss: 0.0028, MSE: 0.0028, Angle: 0.0000, Bone: 0.0002
# Train Step [800/2874], Total Loss: 0.0062, MSE: 0.0062, Angle: 0.4287, Bone: 0.0003
# Train Step [1000/2874], Total Loss: 0.0049, MSE: 0.0049, Angle: 1.3391, Bone: 0.0005
# Train Step [1200/2874], Total Loss: 0.0041, MSE: 0.0041, Angle: 0.0000, Bone: 0.0000
# Train Step [1400/2874], Total Loss: 0.0074, MSE: 0.0074, Angle: 0.1881, Bone: 0.0001
# Train Step [1600/2874], Total Loss: 0.0023, MSE: 0.0023, Angle: 0.0553, Bone: 0.0001
# Train Step [1800/2874], Total Loss: 0.0035, MSE: 0.0035, Angle: 1.0947, Bone: 0.0003
# Train Step [2000/2874], Total Loss: 0.0060, MSE: 0.0060, Angle: 1.0775, Bone: 0.0002
# Train Step [2200/2874], Total Loss: 0.0093, MSE: 0.0093, Angle: 0.7884, Bone: 0.0003
# Train Step [2400/2874], Total Loss: 0.0086, MSE: 0.0086, Angle: 0.0205, Bone: 0.0002
# Train Step [2600/2874], Total Loss: 0.0134, MSE: 0.0134, Angle: 0.1594, Bone: 0.0002
# Train Step [2800/2874], Total Loss: 0.0016, MSE: 0.0016, Angle: 0.0461, Bone: 0.0000
# Test Step [200/381], Total Loss: 0.0050, MSE: 0.0050, Angle: 0.3570, Bone: 0.0002
# Epoch [25/25], Train Loss: 0.0082, Test Loss: 0.0072

# %% [markdown]
# ### ⭐ Calculate MPJPE (Mean Per Joint Position Error) / MPVE (Mean Per Joint Velocity Error)
# - Goal: MPJPE < 0.10~0.20 m (10–20cm), MPVE < ~1cm/s

# %%
def compute_mpjpe(predictions, targets):
    """
    predictions, targets: (B, T, J, 3)
    Returns: scalar MPJPE (in meters)
    """
    error = torch.norm(predictions - targets, dim=-1)  # (B, T, J)
    return error.mean().item()

def compute_mpve(predictions, targets):
    """
    predictions, targets: (B, T, J, 3)
    Returns: scalar MPVE (in m/s)
    """
    pred_velocity = predictions[:, 1:, :, :] - predictions[:, :-1, :, :]  # (B, T-1, J, 3)
    target_velocity = targets[:, 1:, :, :] - targets[:, :-1, :, :]        # (B, T-1, J, 3)

    velocity_error = torch.norm(pred_velocity - target_velocity, dim=-1)  # (B, T-1, J)
    return velocity_error.mean().item()

# %%
# Evaluation loop
model.eval()

# Initialize accumulators
epoch_test_loss = 0
epoch_test_mse = 0
epoch_test_angle = 0
epoch_test_bone = 0
epoch_test_mpjpe = 0
epoch_test_mpve = 0

metrics = {
    'train_loss': [],
    'test_loss': [],
    'train_mse': [],
    'test_mse': [],
    'train_angle': [],
    'test_angle': [],
    'train_bone': [],
    'test_bone': [],
     'test_mpjpe': [],  
    'test_mpve': []
}

with torch.no_grad():
    for i, batch in enumerate(test_dataloader):
        #Move batch data onto device
        batch = {k: v.to(device, non_blocking=True) for k, v in batch.items()}


        # Forward pass
        outputs = model(batch['imu'])  # Shape: (B, T*J*3)
        outputs_reshaped = outputs.view(*batch['mocap'].shape)  # (B, T, J, 3)

        # Loss components
        mse_loss = F.mse_loss(outputs_reshaped, batch['mocap'])
        angle_loss = angle_constraint_loss(outputs_reshaped, alpha=angle_weight)
        bone_loss = bone_length_consistency_loss(outputs_reshaped, alpha=bone_length_weight)
        # total_loss = mse_loss + angle_loss + bone_loss
        total_loss = mse_loss

        # Accumulate losses
        epoch_test_loss += total_loss.item()
        epoch_test_mse += mse_loss.item()
        epoch_test_angle += angle_loss.item()
        epoch_test_bone += bone_loss.item()

        # ➕ Compute MPJPE and MPVE
        epoch_test_mpjpe += compute_mpjpe(outputs_reshaped, batch['mocap'])
        epoch_test_mpve += compute_mpve(outputs_reshaped, batch['mocap'])

        if (i + 1) % 10 == 0:
            print(f'Test Step [{i+1}/{len(test_dataloader)}], '
                  f'Total Loss: {total_loss.item():.4f}, '
                  f'MSE: {mse_loss.item():.4f}, '
                  f'Angle: {angle_loss.item():.4f}, '
                  f'Bone: {bone_loss.item():.4f}')

# Average over all batches
epoch_test_loss /= len(test_dataloader)
epoch_test_mse /= len(test_dataloader)
epoch_test_angle /= len(test_dataloader)
epoch_test_bone /= len(test_dataloader)
epoch_test_mpjpe /= len(test_dataloader)
epoch_test_mpve /= len(test_dataloader)

# Store metrics
metrics['test_loss'].append(epoch_test_loss)
metrics['test_mse'].append(epoch_test_mse)
metrics['test_angle'].append(epoch_test_angle)
metrics['test_bone'].append(epoch_test_bone)
metrics['test_mpjpe'].append(epoch_test_mpjpe)
metrics['test_mpve'].append(epoch_test_mpve)

# Summary
print(f'Epoch [{epoch+1}/{num_epochs}], '
      f'Test Loss: {epoch_test_loss:.4f}, '
      f'MSE: {epoch_test_mse:.4f} ',
      f'MPJPE: {epoch_test_mpjpe:.4f}, '
      f'MPVE: {epoch_test_mpve:.4f}')
# Out:
# Test Step [10/381], Total Loss: 0.0037, MSE: 0.0037, Angle: 0.2537, Bone: 0.0002
# Test Step [20/381], Total Loss: 0.0216, MSE: 0.0216, Angle: 0.0001, Bone: 0.0001
# Test Step [30/381], Total Loss: 0.0099, MSE: 0.0099, Angle: 0.3604, Bone: 0.0004
# Test Step [40/381], Total Loss: 0.0068, MSE: 0.0068, Angle: 0.0936, Bone: 0.0001
# Test Step [50/381], Total Loss: 0.0029, MSE: 0.0029, Angle: 0.8489, Bone: 0.0002
# Test Step [60/381], Total Loss: 0.0039, MSE: 0.0039, Angle: 0.0000, Bone: 0.0002
# Test Step [70/381], Total Loss: 0.0092, MSE: 0.0092, Angle: 0.0832, Bone: 0.0003
# Test Step [80/381], Total Loss: 0.0037, MSE: 0.0037, Angle: 0.0045, Bone: 0.0002
# Test Step [90/381], Total Loss: 0.0062, MSE: 0.0062, Angle: 0.3265, Bone: 0.0003
# Test Step [100/381], Total Loss: 0.0048, MSE: 0.0048, Angle: 0.3653, Bone: 0.0002
# Test Step [110/381], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.4318, Bone: 0.0003
# Test Step [120/381], Total Loss: 0.0049, MSE: 0.0049, Angle: 0.0025, Bone: 0.0001
# Test Step [130/381], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.0360, Bone: 0.0003
# Test Step [140/381], Total Loss: 0.0078, MSE: 0.0078, Angle: 0.0000, Bone: 0.0001
# Test Step [150/381], Total Loss: 0.0094, MSE: 0.0094, Angle: 0.4918, Bone: 0.0003
# Test Step [160/381], Total Loss: 0.0060, MSE: 0.0060, Angle: 0.2612, Bone: 0.0002
# Test Step [170/381], Total Loss: 0.0073, MSE: 0.0073, Angle: 0.0767, Bone: 0.0002
# Test Step [180/381], Total Loss: 0.0067, MSE: 0.0067, Angle: 0.5249, Bone: 0.0004
# Test Step [190/381], Total Loss: 0.0098, MSE: 0.0098, Angle: 0.4991, Bone: 0.0002
# Test Step [200/381], Total Loss: 0.0050, MSE: 0.0050, Angle: 0.3570, Bone: 0.0002
# Test Step [210/381], Total Loss: 0.0055, MSE: 0.0055, Angle: 0.4467, Bone: 0.0003
# Test Step [220/381], Total Loss: 0.0096, MSE: 0.0096, Angle: 0.3373, Bone: 0.0002
# Test Step [230/381], Total Loss: 0.0052, MSE: 0.0052, Angle: 0.7854, Bone: 0.0002
# Test Step [240/381], Total Loss: 0.0066, MSE: 0.0066, Angle: 0.1080, Bone: 0.0002
# Test Step [250/381], Total Loss: 0.0058, MSE: 0.0058, Angle: 0.0000, Bone: 0.0002
# Test Step [260/381], Total Loss: 0.0254, MSE: 0.0254, Angle: 0.0005, Bone: 0.0008
# Test Step [270/381], Total Loss: 0.0075, MSE: 0.0075, Angle: 0.0373, Bone: 0.0001
# Test Step [280/381], Total Loss: 0.0046, MSE: 0.0046, Angle: 0.0000, Bone: 0.0001
# Test Step [290/381], Total Loss: 0.0093, MSE: 0.0093, Angle: 0.0000, Bone: 0.0001
# Test Step [300/381], Total Loss: 0.0103, MSE: 0.0103, Angle: 0.0157, Bone: 0.0001
# Test Step [310/381], Total Loss: 0.0106, MSE: 0.0106, Angle: 0.0552, Bone: 0.0002
# Test Step [320/381], Total Loss: 0.0075, MSE: 0.0075, Angle: 0.0018, Bone: 0.0001
# Test Step [330/381], Total Loss: 0.0043, MSE: 0.0043, Angle: 0.0854, Bone: 0.0001
# Test Step [340/381], Total Loss: 0.0072, MSE: 0.0072, Angle: 0.2866, Bone: 0.0002
# Test Step [350/381], Total Loss: 0.0111, MSE: 0.0111, Angle: 0.1096, Bone: 0.0001
# Test Step [360/381], Total Loss: 0.0123, MSE: 0.0123, Angle: 0.0002, Bone: 0.0002
# Test Step [370/381], Total Loss: 0.0131, MSE: 0.0131, Angle: 0.0000, Bone: 0.0000
# Test Step [380/381], Total Loss: 0.0026, MSE: 0.0026, Angle: 0.3984, Bone: 0.0002
# Epoch [25/25], Test Loss: 0.0072, MSE: 0.0072  MPJPE: 0.1152, MPVE: 0.0051

# %% [markdown]
# ### ⭐ Evaluate Model performance

# %%
# after outputs_reshaped is computed
mpjpe = compute_mpjpe(outputs_reshaped, batch['mocap'])
mpve = compute_mpve(outputs_reshaped, batch['mocap'])

epoch_test_mpjpe += mpjpe
epoch_test_mpve += mpve

print(epoch_test_mpjpe)
print(epoch_test_mpve)
# Out:
# 0.1745777981957113
# 0.012957411826761767
